# %%
from pathlib import Path
import sys

# assume notebook is in: <repo_root>/notebooks
ROOT = Path.cwd().parent          # go up from notebooks → repo root
SRC = ROOT / "src"

if str(SRC) not in sys.path:
    sys.path.append(str(SRC))

from track_meta import TRACK_METAS

# %%
vir_meta = TRACK_METAS["virginia-international-raceway"]
vir_meta
# Out:
# TrackMeta(track_id='virginia-international-raceway', name='Virginia International Raceway', circuit_length_m=5262.6, sector_lengths_m=[1652.6, 2158.0, 1452.0], pit_lane_time_s=25.0, pit_lane_length_m=340.6, gps_finish=(36.5688167, -79.2066639), gps_pit_in=(36.567581, -79.210428), gps_pit_out=(36.568667, -79.206797), pit_in_from_sf_m=4898.7, pit_out_from_sfp_m=-16.0)

# %%
ROOT = Path("/Users/macbook/Desktop/FPTAI/DataScienceHackbyToyota")
SRC = ROOT / "src"
sys.path.append(str(SRC))
from track_meta import TRACK_METAS

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent        # assuming notebook is in /notebooks
SRC = ROOT / "src"

if str(SRC) not in sys.path:
    sys.path.append(str(SRC))

from track_meta import TRACK_METAS

vir_meta = TRACK_METAS["virginia-international-raceway"]
vir_meta
# Out:
# TrackMeta(track_id='virginia-international-raceway', name='Virginia International Raceway', circuit_length_m=5262.6, sector_lengths_m=[1652.6, 2158.0, 1452.0], pit_lane_time_s=25.0, pit_lane_length_m=340.6, gps_finish=(36.5688167, -79.2066639), gps_pit_in=(36.567581, -79.210428), gps_pit_out=(36.568667, -79.206797), pit_in_from_sf_m=4898.7, pit_out_from_sfp_m=-16.0)

# %%
from pathlib import Path

RAW_DIR = ROOT / "data" / "raw" / "virginia"
list(RAW_DIR.glob("*.csv"))
# Out:
# []

# %%
import pandas as pd

LAP_PATH = RAW_DIR / "R2_vir_lap_time.csv"  # <-- CHANGE this to your real file
df_laps_raw = pd.read_csv(LAP_PATH)
df_laps_raw.head()
df_laps_raw.columns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 import pandas as pd
#       3 LAP_PATH = RAW_DIR / "R2_vir_lap_time.csv"  # <-- CHANGE this to your real file
# ----> 4 df_laps_raw = pd.read_csv(LAP_PATH)
#       5 df_laps_raw.head()
#       6 df_laps_raw.columns
#
# ...
